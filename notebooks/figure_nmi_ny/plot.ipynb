# %%
iid_tsne_nmi = [0.628810158573162, 0.6695593883199277, 0.7346236138199344, 0.738708015464625, 0.7676733911546723, 0.7725859167420951, 0.7835944351283287]
iid_umap_nmi = [0.6415972638039074, 0.7182652004086895, 0.7359847724538433, 0.7492105506206107, 0.8145205798068789, 0.813812763451043, 0.8399450870532434]
noniid_tsne_nmi = [0.6307686308912778, 0.6967030429658543, 0.7349569598645083, 0.7646888631117544, 0.7930514781989314, 0.7981159770801085, 0.7858284695979414]
# noniid_tsne_nmi = [0.6237979239525742, 0.684057376514833, 0.7335570431901404, 0.7535074313452181, 0.7362408432184366, 0.7497177106842119, 0.7608831527704683]
noniid_umap_nmi = [0.6281790980134042, 0.6701219289993484, 0.7773969104013075, 0.7989566218650436, 0.8226647621953962, 0.8163883694261992, 0.8247842503081254]

# %%
import matplotlib.pyplot as plt

# 创建一个图形对象
nY = [50, 100, 200, 500, 1000, 2000, 3000]
plt.figure(figsize=(10, 6))

indices = list(range(len(nY)))

# 绘制四条曲线
plt.plot(indices, iid_tsne_nmi, label='IID Fed-tSNE', marker='o', color='b', markersize=10)
plt.plot(indices, noniid_tsne_nmi, label='non-IID Fed-tSNE', marker='o', color='r', markersize=10)
plt.plot(indices, iid_umap_nmi, label='IID Fed-UMAP', marker="^", color='b', markersize=10)
plt.plot(indices, noniid_umap_nmi, label='non-IID Fed-UMAP', marker="^", color='r', markersize=10)

# 添加标题和标签
plt.xlabel('Y Size', fontsize=12)
plt.ylabel('NMI', fontsize=12)
plt.legend(fontsize=12)
plt.xticks(indices, nY, fontsize=12)

# 显示图形
plt.grid(True)
plt.show()
