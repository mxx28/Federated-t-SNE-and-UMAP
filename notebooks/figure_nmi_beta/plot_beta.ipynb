# %%
iid_tsne_nmi = [0.73828799742273, 0.7448428687016797, 0.7401959234133599, 0.7357153541343756, 0.7179505035317028, 0.7300890659752692, 0.7268858425811229, 0.6919606604293898]
# iid_umap_nmi = [0.7491095222036015, 0.7763399853564632, 0.7642532747751847, 0.8131628326067597, 0.8058702615796476, 0.781907221359934, 0.7728301686706498, 0.7408613167189776]
iid_umap_nmi = [0.7869245910614778, 0.801597181646784, 0.7628074686446634, 0.7554079465947725, 0.7465575132212422, 0.743915273324493, 0.7482758923757636, 0.7223382100027825]
noniid_tsne_nmi = [0.7647212021363158, 0.7351269203820744, 0.7142475498232798, 0.6859508617438261, 0.6829134643628315, 0.6910481955883839, 0.6660031378509532, 0.6581766648723166]
# noniid_umap_nmi = [0.7708852926605699, 0.6828991478723919, 0.6655247452433235, 0.6231938788077523, 0.5005609954250184, 0.48738273394412474, 0.5781484390018641, 0.6861482073725316]
noniid_umap_nmi = [0.810679024588452, 0.7843754186719627, 0.780088958525021, 0.7230697981582332, 0.6954196454594572, 0.6832901515239597, 0.6342488022162518, 0.6469694158316022]
# noniid_umap_nmi = [0.7818573721333544, 0.7816490208724947, 0.6926787575041232, 0.7351355054098005, 0.6981977497616848, 0.6729780826407689, 0.6655602954505436, 0.6416588483337095]

# %%
import matplotlib.pyplot as plt

# 创建一个图形对象
beta_list = [0.0, 0.2, 0.5, 1, 2, 3, 4, 5]
plt.figure(figsize=(10, 6))
indices = list(range(len(beta_list)))

# 绘制四条曲线
plt.plot(indices, iid_tsne_nmi, label='IID Fed-tSNE', marker='o', color='b', markersize=10)
plt.plot(indices, noniid_tsne_nmi, label='non-IID Fed-tSNE', marker='o', color='r', markersize=10)
plt.plot(indices, iid_umap_nmi, label='IID Fed-UMAP', marker="^", color='b', markersize=10)
plt.plot(indices, noniid_umap_nmi, label='non-IID Fed-UMAP', marker="^", color='r', markersize=10)

# 添加标题和标签
plt.xlabel('beta', fontsize=12)
plt.ylabel('NMI', fontsize=12)
plt.legend(fontsize=12)
plt.xticks(indices, beta_list, fontsize=12)

# 显示图形
plt.grid(True)
plt.show()
